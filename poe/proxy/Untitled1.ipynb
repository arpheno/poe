# %%
import dis
c=5

# %%
def add(a,b):
    print(c)
    return add(a,b)
dis.dis(add)
# Out:
#   1           0 RESUME                   0
#
#   2           2 LOAD_GLOBAL              1 (NULL + print)
#              14 LOAD_GLOBAL              2 (c)
#              26 PRECALL                  1
#              30 CALL                     1
#              40 POP_TOP
#
#   3          42 LOAD_GLOBAL              5 (NULL + add)
#              54 LOAD_FAST                0 (a)
#              56 LOAD_FAST                1 (b)
#              58 PRECALL                  2
#              62 CALL                     2
#              72 RETURN_VALUE
